# %%
import pandas as pd

pd.set_option('display.max_columns', None)

df_desempenho = pd.read_csv('desempenho_pilotos.csv')
df_desempenho
# Out:
#        Unnamed: 0  driverId forename     surname code  number  raceId  year  \
# 0               0       830      Max  Verstappen  VER      33    1121  2024
# 1               1       830      Max  Verstappen  VER      33    1121  2024
# 2               2       830      Max  Verstappen  VER      33    1121  2024
# 3               3       830      Max  Verstappen  VER      33    1121  2024
# 4               4       830      Max  Verstappen  VER      33    1121  2024
# ...           ...       ...      ...         ...  ...     ...     ...   ...
# 12517       12517       858    Logan    Sargeant  SAR       2    1131  2024
# 12518       12518       858    Logan    Sargeant  SAR       2    1131  2024
# 12519       12519       858    Logan    Sargeant  SAR       2    1131  2024
# 12520       12520       858    Logan    Sargeant  SAR       2    1131  2024
# 12521       12521       858    Logan    Sargeant  SAR       2    1131  2024
#
# ...

# %%
first_lap = df_desempenho[df_desempenho['lap'] == 1]
first_lap
mid_lap = df_desempenho[df_desempenho['lap'] == 55]
mid_lap
final_lap = df_desempenho[df_desempenho['lap'] == 71]
first_lap
# Out:
#        Unnamed: 0  driverId  forename     surname code  number  raceId  year  \
# 0               0       830       Max  Verstappen  VER      33    1121  2024
# 57             57       844   Charles     Leclerc  LEC      16    1121  2024
# 114           114       847    George     Russell  RUS      63    1121  2024
# 171           171       815    Sergio       Pérez  PER      11    1121  2024
# 228           228       832    Carlos       Sainz  SAI      55    1121  2024
# ...           ...       ...       ...         ...  ...     ...     ...   ...
# 12172       12172       822  Valtteri      Bottas  BOT      77    1131  2024
# 12242       12242       840     Lance      Stroll  STR      18    1131  2024
# 12312       12312       844   Charles     Leclerc  LEC      16    1131  2024
# 12383       12383       855    Guanyu        Zhou  ZHO      24    1131  2024
# 12453       12453       858     Logan    Sargeant  SAR       2    1131  2024
#
# ...
